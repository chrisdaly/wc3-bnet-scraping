# %%
import os
import json
import pandas as pd

# %%
servers = ['azeroth']#, 'northrend']
for server in servers:
    dir_ = './data_backfill/partial/{}'.format(server)
    file_names = os.listdir(dir_)
    file_names = [x for x in file_names if not x.startswith(".")]

    data = []
    for file_name in file_names:
        print(file_name)
        file_path = '{}/{}'.format(dir_, file_name)
        with open(file_path, 'r', encoding='utf-8') as f:
            g = json.loads(f.read())
            data.extend(g)

    with open('./data_backfill/{}.json'.format(server), 'w') as f:
        json.dump(data, f)
# Out:
# Anewb..json
# AnoM.json
# Ceron.json
# Che.json
# Cocaine..json
# Divine-.json
# Fithydenk.json
# girls-love-me.json
# Lado.json
# lRain.json
# Ludique.json
# LynPark.json
# OnlyYou.json
# Patience.json
# Pieck.json
# PracticeDrannor.json
# RAGE.Believe.json
# SADIST-ANANIST.json
# ShilOhS.json
# Shodan.Guy.json

# %%
data
# Out:
# [{'date': '2019-01-31 15:52:00',
#   'game_id': 23235953,
#   'game_length': 16,
#   'game_type': 'Solo',
#   'map': 'Last Refuge',
#   'team_one': ['Anewb.'],
#   'team_two': ['htrt'],
#   'winner': ['htrt']},
#  {'date': '2019-01-31 15:33:00',
#   'game_id': 23235935,
#   'game_length': 12,
#   'game_type': 'Solo',
#   'map': 'Amazonia',
#   'team_one': ['Anewb.'],
#   'team_two': ['Lado'],
#   'winner': ['Lado']},
#  {'date': '2019-01-31 15:19:00',
#   'game_id': 23235921,
#   'game_length': 6,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['Anewb.'],
#   'team_two': ['180'],
#   'winner': ['Anewb.']},
#  {'date': '2019-01-31 15:08:00',
#   'game_id': 23235907,
#   'game_length': 4,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['Anewb.'],
#   'team_two': ['RAGE.Believe'],
#   'winner': ['Anewb.']},
#  {'date': '2019-01-31 15:03:00',
#   'game_id': 23235901,
#   'game_length': 17,
#   'game_type': 'Solo',
#   'map': 'Twisted Meadows',
#   'team_one': ['Anewb.'],
#   'team_two': ['EvilMan420'],
#   'winner': ['Anewb.']},
#  {'date': '2019-01-31 14:44:00',
#   'game_id': 23235872,
#   'game_length': 10,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['Anewb.'],
#   'team_two': ['TurkishGold'],
#   'winner': ['Anewb.']},
#  {'date': '2019-01-31 14:28:00',
#   'game_id': 23235857,
#   'game_length': 17,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['Anewb.'],
#   'team_two': ['MuscleMike'],
#   'winner': ['Anewb.']},
#  {'date': '2019-01-31 14:10:00',
#   'game_id': 23235830,
#   'game_length': 4,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['Anewb.'],
#   'team_two': ['HoldMyBeer'],
#   'winner': ['Anewb.']},
#  {'date': '2019-01-31 14:03:00',
#   'game_id': 23235821,
#   'game_length': 10,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['Anewb.'],
#   'team_two': ['kpxandy'],
#   'winner': ['Anewb.']},
#  {'date': '2019-01-31 13:50:00',
#   'game_id': 23235802,
#   'game_length': 3,
#   'game_type': 'Solo',
#   'map': 'Amazonia',
#   'team_one': ['Anewb.'],
#   'team_two': ['bromley'],
#   'winner': ['Anewb.']},
#  {'date': '2019-01-31 13:45:00',
#   'game_id': 23235796,
#   'game_length': 6,
#   'game_type': 'Solo',
#   'map': 'Amazonia',
#   'team_one': ['Anewb.'],
#   'team_two': ['RAGE.Rendition'],
#   'winner': ['Anewb.']},
#  {'date': '2019-01-31 13:36:00',
#   'game_id': 23235787,
#   'game_length': 13,
#   'game_type': 'Solo',
#   'map': 'Amazonia',
#   'team_one': ['Anewb.'],
#   'team_two': ['htrt'],
#   'winner': ['htrt']},
#  {'date': '2018-11-30 19:25:00',
#   'game_id': 23229769,
#   'game_length': 19,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['Anewb.'],
#   'team_two': ['sayso.'],
#   'winner': ['sayso.']},
#  {'date': '2018-11-30 19:04:00',
#   'game_id': 23229736,
#   'game_length': 3,
#   'game_type': 'Solo',
#   'map': 'Twisted Meadows',
#   'team_one': ['Anewb.'],
#   'team_two': ['GoblazIsBad'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-30 18:41:00',
#   'game_id': 23229692,
#   'game_length': 17,
#   'game_type': 'Solo',
#   'map': 'Amazonia',
#   'team_one': ['Anewb.'],
#   'team_two': ['Ceron'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-30 18:22:00',
#   'game_id': 23229660,
#   'game_length': 0,
#   'game_type': 'Solo',
#   'map': 'Concealed Hill',
#   'team_one': ['Anewb.'],
#   'team_two': ['All-X'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-30 18:18:00',
#   'game_id': 23229652,
#   'game_length': 1,
#   'game_type': 'Solo',
#   'map': 'Amazonia',
#   'team_one': ['Anewb.'],
#   'team_two': ['HYPEHYPE'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-30 18:12:00',
#   'game_id': 23229639,
#   'game_length': 8,
#   'game_type': 'Solo',
#   'map': 'Last Refuge',
#   'team_one': ['Anewb.'],
#   'team_two': ['Lado'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-30 18:02:00',
#   'game_id': 23229622,
#   'game_length': 12,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['Anewb.'],
#   'team_two': ['STLER'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-30 17:46:00',
#   'game_id': 23229588,
#   'game_length': 12,
#   'game_type': 'Solo',
#   'map': 'Concealed Hill',
#   'team_one': ['Anewb.'],
#   'team_two': ['^_^`'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-30 17:31:00',
#   'game_id': 23229569,
#   'game_length': 0,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['Anewb.'],
#   'team_two': ['56789576'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-30 17:29:00',
#   'game_id': 23229568,
#   'game_length': 5,
#   'game_type': 'Solo',
#   'map': 'Twisted Meadows',
#   'team_one': ['Anewb.'],
#   'team_two': ['PaxRomana'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-30 17:21:00',
#   'game_id': 23229555,
#   'game_length': 5,
#   'game_type': 'Solo',
#   'map': 'Twisted Meadows',
#   'team_one': ['Anewb.'],
#   'team_two': ['IIIIIIIlllIIIII'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-29 22:14:00',
#   'game_id': 23228310,
#   'game_length': 7,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['Anewb.'],
#   'team_two': ['RenditionRG_FF'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-29 22:04:00',
#   'game_id': 23228289,
#   'game_length': 9,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['Anewb.'],
#   'team_two': ['inferno272'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-29 21:53:00',
#   'game_id': 23228234,
#   'game_length': 11,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['Anewb.'],
#   'team_two': ['BOBESPONJA'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-29 21:39:00',
#   'game_id': 23228203,
#   'game_length': 12,
#   'game_type': 'Solo',
#   'map': 'Amazonia',
#   'team_one': ['Anewb.'],
#   'team_two': ['MuscleMike'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-29 21:25:00',
#   'game_id': 23228181,
#   'game_length': 16,
#   'game_type': 'Solo',
#   'map': 'Concealed Hill',
#   'team_one': ['Anewb.'],
#   'team_two': ['PieCk'],
#   'winner': ['PieCk']},
#  {'date': '2018-11-28 17:50:00',
#   'game_id': 23225664,
#   'game_length': 12,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['Anewb.'],
#   'team_two': ['kingShip'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-28 17:33:00',
#   'game_id': 23225641,
#   'game_length': 12,
#   'game_type': 'Solo',
#   'map': 'Last Refuge',
#   'team_one': ['Anewb.'],
#   'team_two': ['JustForFun'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-28 17:19:00',
#   'game_id': 23225626,
#   'game_length': 9,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['Anewb.'],
#   'team_two': ['niGhT-BlOoDy'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-28 17:09:00',
#   'game_id': 23225608,
#   'game_length': 6,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['Anewb.'],
#   'team_two': ['hvitserk^'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-28 16:57:00',
#   'game_id': 23225589,
#   'game_length': 0,
#   'game_type': 'Solo',
#   'map': 'Concealed Hill',
#   'team_one': ['Anewb.'],
#   'team_two': ['lvyiwei1'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-28 16:57:00',
#   'game_id': 23225586,
#   'game_length': 12,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['Anewb.'],
#   'team_two': ['doj.'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-28 16:43:00',
#   'game_id': 23225567,
#   'game_length': 6,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['Anewb.'],
#   'team_two': ['pat_martin'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-28 16:34:00',
#   'game_id': 23225552,
#   'game_length': 6,
#   'game_type': 'Solo',
#   'map': 'Amazonia',
#   'team_one': ['Anewb.'],
#   'team_two': ['TTime'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-28 16:21:00',
#   'game_id': 23225527,
#   'game_length': 2,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['Anewb.'],
#   'team_two': ['Lado'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-28 16:15:00',
#   'game_id': 23225513,
#   'game_length': 1,
#   'game_type': 'Solo',
#   'map': 'Last Refuge',
#   'team_one': ['Anewb.'],
#   'team_two': ['Tennisman1234'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-28 16:11:00',
#   'game_id': 23225509,
#   'game_length': 3,
#   'game_type': 'Solo',
#   'map': 'Twisted Meadows',
#   'team_one': ['Anewb.'],
#   'team_two': ['Smurfo'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-28 16:05:00',
#   'game_id': 23225502,
#   'game_length': 3,
#   'game_type': 'Solo',
#   'map': 'Amazonia',
#   'team_one': ['Anewb.'],
#   'team_two': ['sPG]PapiWallace'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-28 16:00:00',
#   'game_id': 23225495,
#   'game_length': 5,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['Anewb.'],
#   'team_two': ['RenditionRG_FF'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-28 15:52:00',
#   'game_id': 23225466,
#   'game_length': 9,
#   'game_type': 'Solo',
#   'map': 'Concealed Hill',
#   'team_one': ['Anewb.'],
#   'team_two': ['NightStartt'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-28 15:38:00',
#   'game_id': 23225450,
#   'game_length': 11,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['Anewb.'],
#   'team_two': ['Pitu.Leugim'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-28 15:21:00',
#   'game_id': 23225435,
#   'game_length': 9,
#   'game_type': 'Solo',
#   'map': 'Amazonia',
#   'team_one': ['Anewb.'],
#   'team_two': ['SleepyOwlzy'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-27 20:32:00',
#   'game_id': 23224115,
#   'game_length': 17,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['Anewb.'],
#   'team_two': ['YamaF-15E'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-27 20:13:00',
#   'game_id': 23224059,
#   'game_length': 7,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['Anewb.'],
#   'team_two': ['gg.kanzer'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-27 20:02:00',
#   'game_id': 23224040,
#   'game_length': 10,
#   'game_type': 'Solo',
#   'map': 'Last Refuge',
#   'team_one': ['Anewb.'],
#   'team_two': ['Drunkomick'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-27 19:49:00',
#   'game_id': 23223995,
#   'game_length': 3,
#   'game_type': 'Solo',
#   'map': 'Last Refuge',
#   'team_one': ['Anewb.'],
#   'team_two': ['IhsahN'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-27 19:43:00',
#   'game_id': 23223981,
#   'game_length': 11,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['Anewb.'],
#   'team_two': ['WuLord'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-27 19:28:00',
#   'game_id': 23223954,
#   'game_length': 12,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['Anewb.'],
#   'team_two': ['xcarlx'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-27 19:12:00',
#   'game_id': 23223922,
#   'game_length': 8,
#   'game_type': 'Solo',
#   'map': 'Twisted Meadows',
#   'team_one': ['Anewb.'],
#   'team_two': ['DRAHYRT'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-27 18:52:00',
#   'game_id': 23223858,
#   'game_length': 18,
#   'game_type': 'Solo',
#   'map': 'Concealed Hill',
#   'team_one': ['Anewb.'],
#   'team_two': ['PieCk'],
#   'winner': ['PieCk']},
#  {'date': '2018-11-27 18:33:00',
#   'game_id': 23223825,
#   'game_length': 19,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['Anewb.'],
#   'team_two': ['lRAIN'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-27 18:10:00',
#   'game_id': 23223797,
#   'game_length': 5,
#   'game_type': 'Solo',
#   'map': 'Last Refuge',
#   'team_one': ['Anewb.'],
#   'team_two': ['Animus'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-27 18:03:00',
#   'game_id': 23223787,
#   'game_length': 0,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['Anewb.'],
#   'team_two': ['NeUdHuOrc'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-27 17:57:00',
#   'game_id': 23223769,
#   'game_length': 9,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['Anewb.'],
#   'team_two': ['FuKLeR'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-26 23:30:00',
#   'game_id': 23222708,
#   'game_length': 10,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['Anewb.'],
#   'team_two': ['infs]elves'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-26 23:18:00',
#   'game_id': 23222695,
#   'game_length': 8,
#   'game_type': 'Solo',
#   'map': 'Amazonia',
#   'team_one': ['Anewb.'],
#   'team_two': ['Daangel'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-26 23:08:00',
#   'game_id': 23222673,
#   'game_length': 0,
#   'game_type': 'Solo',
#   'map': 'Amazonia',
#   'team_one': ['Anewb.'],
#   'team_two': ['ACupofcoke'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-26 23:05:00',
#   'game_id': 23222669,
#   'game_length': 10,
#   'game_type': 'Solo',
#   'map': 'Concealed Hill',
#   'team_one': ['Anewb.'],
#   'team_two': ['SuperNewbie'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-26 22:52:00',
#   'game_id': 23222594,
#   'game_length': 12,
#   'game_type': 'Solo',
#   'map': 'Amazonia',
#   'team_one': ['Anewb.'],
#   'team_two': ['Che'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-26 22:38:00',
#   'game_id': 23222556,
#   'game_length': 0,
#   'game_type': 'Solo',
#   'map': 'Twisted Meadows',
#   'team_one': ['Anewb.'],
#   'team_two': ['Hong'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-26 22:34:00',
#   'game_id': 23222527,
#   'game_length': 27,
#   'game_type': 'Solo',
#   'map': 'Twisted Meadows',
#   'team_one': ['Anewb.'],
#   'team_two': ['Cocaine.'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-26 22:05:00',
#   'game_id': 23222475,
#   'game_length': 8,
#   'game_type': 'Solo',
#   'map': 'Concealed Hill',
#   'team_one': ['Anewb.'],
#   'team_two': ['JAPAPITO'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-26 21:54:00',
#   'game_id': 23222435,
#   'game_length': 6,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['Anewb.'],
#   'team_two': ['TRUCKSTOP'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-26 21:45:00',
#   'game_id': 23222421,
#   'game_length': 7,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['Anewb.'],
#   'team_two': ['YouShuLa'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-26 21:36:00',
#   'game_id': 23222398,
#   'game_length': 9,
#   'game_type': 'Solo',
#   'map': 'Amazonia',
#   'team_one': ['Anewb.'],
#   'team_two': ['RAGE.NERZHUL'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-26 21:21:00',
#   'game_id': 23222366,
#   'game_length': 11,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['Anewb.'],
#   'team_two': ['elchavodel8'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-26 21:08:00',
#   'game_id': 23222286,
#   'game_length': 16,
#   'game_type': 'Solo',
#   'map': 'Twisted Meadows',
#   'team_one': ['Anewb.'],
#   'team_two': ['Fkc)Kanon'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-26 20:49:00',
#   'game_id': 23222249,
#   'game_length': 8,
#   'game_type': 'Solo',
#   'map': 'Twisted Meadows',
#   'team_one': ['Anewb.'],
#   'team_two': ['neen'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-26 20:39:00',
#   'game_id': 23222234,
#   'game_length': 8,
#   'game_type': 'Solo',
#   'map': 'Concealed Hill',
#   'team_one': ['Anewb.'],
#   'team_two': ['doflamingoap'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-26 15:55:00',
#   'game_id': 23219105,
#   'game_length': 11,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['Anewb.'],
#   'team_two': ['Cocaine.'],
#   'winner': ['Cocaine.']},
#  {'date': '2018-11-26 15:41:00',
#   'game_id': 23219086,
#   'game_length': 12,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['Anewb.'],
#   'team_two': ['AJJA'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-26 15:27:00',
#   'game_id': 23219070,
#   'game_length': 19,
#   'game_type': 'Solo',
#   'map': 'Concealed Hill',
#   'team_one': ['Anewb.'],
#   'team_two': ['JustForFun'],
#   'winner': ['JustForFun']},
#  {'date': '2018-11-26 14:46:00',
#   'game_id': 23219024,
#   'game_length': 10,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['Anewb.'],
#   'team_two': ['WaitAndSee'],
#   'winner': ['WaitAndSee']},
#  {'date': '2018-11-25 23:21:00',
#   'game_id': 23218389,
#   'game_length': 8,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['Anewb.'],
#   'team_two': ['OldDirtyPlayer'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-25 23:11:00',
#   'game_id': 23218376,
#   'game_length': 3,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['Anewb.'],
#   'team_two': ['Y0uReady'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-25 23:05:00',
#   'game_id': 23218358,
#   'game_length': 15,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['Anewb.'],
#   'team_two': ['Ludique'],
#   'winner': ['Ludique']},
#  {'date': '2018-11-25 22:49:00',
#   'game_id': 23218333,
#   'game_length': 6,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['Anewb.'],
#   'team_two': ['freesouthkorea'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-25 22:39:00',
#   'game_id': 23218317,
#   'game_length': 7,
#   'game_type': 'Solo',
#   'map': 'Concealed Hill',
#   'team_one': ['Anewb.'],
#   'team_two': ['^Divine'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-25 22:30:00',
#   'game_id': 23218297,
#   'game_length': 11,
#   'game_type': 'Solo',
#   'map': 'Last Refuge',
#   'team_one': ['Anewb.'],
#   'team_two': ['Grievertron'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-25 22:16:00',
#   'game_id': 23218273,
#   'game_length': 12,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['Anewb.'],
#   'team_two': ['ANGRY_KOREA_MAN'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-25 20:26:00',
#   'game_id': 23218028,
#   'game_length': 13,
#   'game_type': 'Solo',
#   'map': 'Twisted Meadows',
#   'team_one': ['Anewb.'],
#   'team_two': ['Cocaine.'],
#   'winner': ['Cocaine.']},
#  {'date': '2018-11-25 20:11:00',
#   'game_id': 23218001,
#   'game_length': 19,
#   'game_type': 'Solo',
#   'map': 'Concealed Hill',
#   'team_one': ['Anewb.'],
#   'team_two': ['JustForFun'],
#   'winner': ['JustForFun']},
#  {'date': '2018-11-25 19:51:00',
#   'game_id': 23217968,
#   'game_length': 7,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['Anewb.'],
#   'team_two': ['kitsune'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-25 19:41:00',
#   'game_id': 23217953,
#   'game_length': 9,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['Anewb.'],
#   'team_two': ['slap-happy'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-24 19:49:00',
#   'game_id': 23216015,
#   'game_length': 3,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['Anewb.'],
#   'team_two': ['GenitaIsAndAnuz'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-24 19:43:00',
#   'game_id': 23216004,
#   'game_length': 4,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['Anewb.'],
#   'team_two': ['Murderotica'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-24 19:36:00',
#   'game_id': 23215995,
#   'game_length': 3,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['Anewb.'],
#   'team_two': ['ggglhf'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-24 19:30:00',
#   'game_id': 23215987,
#   'game_length': 13,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['Anewb.'],
#   'team_two': ['soonchi'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-24 19:14:00',
#   'game_id': 23215967,
#   'game_length': 17,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['Anewb.'],
#   'team_two': ['dead_pan_fried'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-24 18:54:00',
#   'game_id': 23215945,
#   'game_length': 0,
#   'game_type': 'Solo',
#   'map': 'Twisted Meadows',
#   'team_one': ['Anewb.'],
#   'team_two': ['cutegirl90'],
#   'winner': None},
#  {'date': '2018-11-24 18:43:00',
#   'game_id': 23215933,
#   'game_length': 18,
#   'game_type': 'Solo',
#   'map': 'Last Refuge',
#   'team_one': ['Anewb.'],
#   'team_two': ['sunriderZ'],
#   'winner': ['sunriderZ']},
#  {'date': '2018-11-24 18:24:00',
#   'game_id': 23215905,
#   'game_length': 17,
#   'game_type': 'Solo',
#   'map': 'Concealed Hill',
#   'team_one': ['Anewb.'],
#   'team_two': ['MIC13'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-24 18:05:00',
#   'game_id': 23215873,
#   'game_length': 9,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['Anewb.'],
#   'team_two': ['RooK709'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-24 17:53:00',
#   'game_id': 23215852,
#   'game_length': 19,
#   'game_type': 'Solo',
#   'map': 'Concealed Hill',
#   'team_one': ['Anewb.'],
#   'team_two': ['AgentShoCKer'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-24 17:31:00',
#   'game_id': 23215811,
#   'game_length': 5,
#   'game_type': 'Solo',
#   'map': 'Amazonia',
#   'team_one': ['Anewb.'],
#   'team_two': ['apollo1001'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-24 17:23:00',
#   'game_id': 23215799,
#   'game_length': 11,
#   'game_type': 'Solo',
#   'map': 'Last Refuge',
#   'team_one': ['Anewb.'],
#   'team_two': ['slap-happy'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-22 19:54:00',
#   'game_id': 23212819,
#   'game_length': 16,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['Anewb.'],
#   'team_two': ['PieCk'],
#   'winner': ['PieCk']},
#  {'date': '2018-11-22 19:30:00',
#   'game_id': 23212781,
#   'game_length': 11,
#   'game_type': 'Solo',
#   'map': 'Concealed Hill',
#   'team_one': ['Anewb.'],
#   'team_two': ['JustForFun'],
#   'winner': ['JustForFun']},
#  {'date': '2018-11-22 19:11:00',
#   'game_id': 23212755,
#   'game_length': 14,
#   'game_type': 'Solo',
#   'map': 'Last Refuge',
#   'team_one': ['Anewb.'],
#   'team_two': ['Cocaine.'],
#   'winner': ['Cocaine.']},
#  {'date': '2018-11-22 18:52:00',
#   'game_id': 23212724,
#   'game_length': 9,
#   'game_type': 'Solo',
#   'map': 'Twisted Meadows',
#   'team_one': ['Anewb.'],
#   'team_two': ['TORETTO'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-22 18:36:00',
#   'game_id': 23212701,
#   'game_length': 11,
#   'game_type': 'Solo',
#   'map': 'Amazonia',
#   'team_one': ['Anewb.'],
#   'team_two': ['MuscleMike'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-22 18:22:00',
#   'game_id': 23212686,
#   'game_length': 9,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['Anewb.'],
#   'team_two': ['Schwick'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-22 18:10:00',
#   'game_id': 23212675,
#   'game_length': 8,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['Anewb.'],
#   'team_two': ['AlanWalker'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-22 17:59:00',
#   'game_id': 23212659,
#   'game_length': 11,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['Anewb.'],
#   'team_two': ['RdmHeroPls'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-21 21:41:00',
#   'game_id': 23211366,
#   'game_length': 14,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['Anewb.'],
#   'team_two': ['jugandoEbrio'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-21 21:24:00',
#   'game_id': 23211335,
#   'game_length': 13,
#   'game_type': 'Solo',
#   'map': 'Last Refuge',
#   'team_one': ['Anewb.'],
#   'team_two': ['PieCk'],
#   'winner': ['PieCk']},
#  {'date': '2018-11-21 21:10:00',
#   'game_id': 23211301,
#   'game_length': 12,
#   'game_type': 'Solo',
#   'map': 'Twisted Meadows',
#   'team_one': ['Anewb.'],
#   'team_two': ['NoMicro'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-21 20:55:00',
#   'game_id': 23211270,
#   'game_length': 6,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['Anewb.'],
#   'team_two': ['tech1356'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-21 20:46:00',
#   'game_id': 23211251,
#   'game_length': 2,
#   'game_type': 'Solo',
#   'map': 'Last Refuge',
#   'team_one': ['Anewb.'],
#   'team_two': ['c1Jer'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-21 20:41:00',
#   'game_id': 23211241,
#   'game_length': 24,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['Anewb.'],
#   'team_two': ['SwordPuppyTv'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-21 20:15:00',
#   'game_id': 23211188,
#   'game_length': 3,
#   'game_type': 'Solo',
#   'map': 'Last Refuge',
#   'team_one': ['Anewb.'],
#   'team_two': ['Votive'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-21 20:07:00',
#   'game_id': 23211169,
#   'game_length': 11,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['Anewb.'],
#   'team_two': ['OnLyYou'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-21 19:54:00',
#   'game_id': 23211147,
#   'game_length': 9,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['Anewb.'],
#   'team_two': ['MuscleMike'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-21 19:42:00',
#   'game_id': 23211118,
#   'game_length': 19,
#   'game_type': 'Solo',
#   'map': 'Twisted Meadows',
#   'team_one': ['Anewb.'],
#   'team_two': ['Shodan.Guy'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-21 19:18:00',
#   'game_id': 23211070,
#   'game_length': 11,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['Anewb.'],
#   'team_two': ['cogniac'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-21 16:06:00',
#   'game_id': 23210777,
#   'game_length': 13,
#   'game_type': 'Solo',
#   'map': 'Concealed Hill',
#   'team_one': ['Anewb.'],
#   'team_two': ['peleando'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-21 15:13:00',
#   'game_id': 23210690,
#   'game_length': 6,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['Anewb.'],
#   'team_two': ['RomanticUD'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-21 15:05:00',
#   'game_id': 23210681,
#   'game_length': 11,
#   'game_type': 'Solo',
#   'map': 'Concealed Hill',
#   'team_one': ['Anewb.'],
#   'team_two': ['narcotic411'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-21 14:51:00',
#   'game_id': 23210658,
#   'game_length': 10,
#   'game_type': 'Solo',
#   'map': 'Amazonia',
#   'team_one': ['Anewb.'],
#   'team_two': ['noob'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-21 14:29:00',
#   'game_id': 23210628,
#   'game_length': 18,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['Anewb.'],
#   'team_two': ['Alf'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-21 14:10:00',
#   'game_id': 23210612,
#   'game_length': 8,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['Anewb.'],
#   'team_two': ['HIRACKSON'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-21 13:57:00',
#   'game_id': 23210597,
#   'game_length': 10,
#   'game_type': 'Solo',
#   'map': 'Last Refuge',
#   'team_one': ['Anewb.'],
#   'team_two': ['-pizza-'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-21 13:45:00',
#   'game_id': 23210586,
#   'game_length': 7,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['Anewb.'],
#   'team_two': ['madfapper'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-21 13:35:00',
#   'game_id': 23210578,
#   'game_length': 23,
#   'game_type': 'Solo',
#   'map': 'Last Refuge',
#   'team_one': ['Anewb.'],
#   'team_two': ['Cocaine.'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-21 13:10:00',
#   'game_id': 23210552,
#   'game_length': 10,
#   'game_type': 'Solo',
#   'map': 'Last Refuge',
#   'team_one': ['Anewb.'],
#   'team_two': ['TeAmoLiesel'],
#   'winner': ['Anewb.']},
#  {'date': '2018-11-21 12:58:00',
#   'game_id': 23210541,
#   'game_length': 6,
#   'game_type': 'Solo',
#   'map': 'Amazonia',
#   'team_one': ['Anewb.'],
#   'team_two': ['twitchhomoGanja'],
#   'winner': ['Anewb.']},
#  {'date': '2019-02-08 02:34:00',
#   'game_id': 23249292,
#   'game_length': 0,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['AnoM'],
#   'team_two': ['herjungchang'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-08 02:15:00',
#   'game_id': 23249274,
#   'game_length': 10,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['tubbykitty'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-08 01:51:00',
#   'game_id': 23249101,
#   'game_length': 13,
#   'game_type': 'Solo',
#   'map': 'Northern Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['Lim'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-08 01:14:00',
#   'game_id': 23249055,
#   'game_length': 5,
#   'game_type': 'Solo',
#   'map': 'Last Refuge',
#   'team_one': ['AnoM'],
#   'team_two': ['InFs]Psycho'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-08 00:38:00',
#   'game_id': 23249001,
#   'game_length': 22,
#   'game_type': 'Solo',
#   'map': 'Amazonia',
#   'team_one': ['AnoM'],
#   'team_two': ['OnLyYou'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-07 23:35:00',
#   'game_id': 23248906,
#   'game_length': 13,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['lawling123'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-07 21:43:00',
#   'game_id': 23248684,
#   'game_length': 18,
#   'game_type': 'Solo',
#   'map': 'Last Refuge',
#   'team_one': ['AnoM'],
#   'team_two': ['sayso.'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-07 21:21:00',
#   'game_id': 23248653,
#   'game_length': 23,
#   'game_type': 'Solo',
#   'map': 'Concealed Hill',
#   'team_one': ['AnoM'],
#   'team_two': ['ABCD'],
#   'winner': ['ABCD']},
#  {'date': '2019-02-07 20:52:00',
#   'game_id': 23248576,
#   'game_length': 13,
#   'game_type': 'Solo',
#   'map': 'Amazonia',
#   'team_one': ['AnoM'],
#   'team_two': ['RAGE.Rendition'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-07 20:33:00',
#   'game_id': 23248546,
#   'game_length': 14,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['birdgang'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-07 18:07:00',
#   'game_id': 23248288,
#   'game_length': 8,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['Carthacus'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-07 17:36:00',
#   'game_id': 23248243,
#   'game_length': 13,
#   'game_type': 'Solo',
#   'map': 'Concealed Hill',
#   'team_one': ['AnoM'],
#   'team_two': ['mississauce'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-07 15:33:00',
#   'game_id': 23246337,
#   'game_length': 8,
#   'game_type': 'Solo',
#   'map': 'Last Refuge',
#   'team_one': ['AnoM'],
#   'team_two': ['MoBamba'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-07 15:18:00',
#   'game_id': 23246318,
#   'game_length': 9,
#   'game_type': 'Solo',
#   'map': 'Northern Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['mrCesar'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-07 15:03:00',
#   'game_id': 23246303,
#   'game_length': 26,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['SADIST-ANANIST'],
#   'winner': ['SADIST-ANANIST']},
#  {'date': '2019-02-07 04:39:00',
#   'game_id': 23245950,
#   'game_length': 10,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['AnoM'],
#   'team_two': ['BoredProphet'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-07 04:21:00',
#   'game_id': 23245940,
#   'game_length': 10,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['AnoM'],
#   'team_two': ['Traveller'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-07 04:05:00',
#   'game_id': 23245934,
#   'game_length': 15,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['gIRLS-love-me'],
#   'winner': ['gIRLS-love-me']},
#  {'date': '2019-02-07 03:43:00',
#   'game_id': 23245922,
#   'game_length': 13,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['YSL-'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-07 03:28:00',
#   'game_id': 23245917,
#   'game_length': 9,
#   'game_type': 'Solo',
#   'map': 'Amazonia',
#   'team_one': ['AnoM'],
#   'team_two': ['ImBadAtThisGame'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-07 03:18:00',
#   'game_id': 23245915,
#   'game_length': 9,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['fragnificent'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-07 03:06:00',
#   'game_id': 23245908,
#   'game_length': 23,
#   'game_type': 'Solo',
#   'map': 'Northern Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['FierCe[GGL]'],
#   'winner': ['FierCe[GGL]']},
#  {'date': '2019-02-07 02:41:00',
#   'game_id': 23245897,
#   'game_length': 3,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['AnoM'],
#   'team_two': ['Empirus'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-07 01:58:00',
#   'game_id': 23245859,
#   'game_length': 10,
#   'game_type': 'Solo',
#   'map': 'Northern Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['^_^`'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-07 01:46:00',
#   'game_id': 23245840,
#   'game_length': 1,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['AnoM'],
#   'team_two': ['ysy0520'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-07 01:44:00',
#   'game_id': 23245837,
#   'game_length': 0,
#   'game_type': 'Solo',
#   'map': 'Last Refuge',
#   'team_one': ['AnoM'],
#   'team_two': ['NetflixAll'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-07 01:29:00',
#   'game_id': 23245813,
#   'game_length': 11,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['AnoM'],
#   'team_two': ['FuriousGeorge'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-07 01:08:00',
#   'game_id': 23245789,
#   'game_length': 9,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['Billyo'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-07 00:53:00',
#   'game_id': 23245774,
#   'game_length': 11,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['doinksinamish'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-06 23:21:00',
#   'game_id': 23245670,
#   'game_length': 12,
#   'game_type': 'Solo',
#   'map': 'Amazonia',
#   'team_one': ['AnoM'],
#   'team_two': ['RAGE^Aretas'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-06 22:59:00',
#   'game_id': 23245640,
#   'game_length': 8,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['qouphi'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-06 22:22:00',
#   'game_id': 23245577,
#   'game_length': 6,
#   'game_type': 'Solo',
#   'map': 'Amazonia',
#   'team_one': ['AnoM'],
#   'team_two': ['FierCe[GGL]'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-06 20:46:00',
#   'game_id': 23245411,
#   'game_length': 11,
#   'game_type': 'Solo',
#   'map': 'Northern Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['PracticeDrannor'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-06 20:27:00',
#   'game_id': 23245380,
#   'game_length': 33,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['AnoM'],
#   'team_two': ['lRAIN'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-06 19:48:00',
#   'game_id': 23245326,
#   'game_length': 23,
#   'game_type': 'Solo',
#   'map': 'Concealed Hill',
#   'team_one': ['AnoM'],
#   'team_two': ['ArianaGrande'],
#   'winner': ['ArianaGrande']},
#  {'date': '2019-02-06 19:18:00',
#   'game_id': 23245279,
#   'game_length': 13,
#   'game_type': 'Solo',
#   'map': 'Last Refuge',
#   'team_one': ['AnoM'],
#   'team_two': ['PieCk'],
#   'winner': ['PieCk']},
#  {'date': '2019-02-06 18:49:00',
#   'game_id': 23245237,
#   'game_length': 16,
#   'game_type': 'Solo',
#   'map': 'Last Refuge',
#   'team_one': ['AnoM'],
#   'team_two': ['WayOfKings'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-06 18:30:00',
#   'game_id': 23245209,
#   'game_length': 11,
#   'game_type': 'Solo',
#   'map': 'Amazonia',
#   'team_one': ['AnoM'],
#   'team_two': ['lasentu40'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-06 18:08:00',
#   'game_id': 23245186,
#   'game_length': 9,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['Nelso'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-06 17:52:00',
#   'game_id': 23245160,
#   'game_length': 22,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['flow'],
#   'winner': ['flow']},
#  {'date': '2019-02-06 17:20:00',
#   'game_id': 23245103,
#   'game_length': 3,
#   'game_type': 'Solo',
#   'map': 'Last Refuge',
#   'team_one': ['AnoM'],
#   'team_two': ['Curiosity'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-06 17:02:00',
#   'game_id': 23245075,
#   'game_length': 9,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['z.Q'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-06 16:42:00',
#   'game_id': 23245047,
#   'game_length': 12,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['soonchi'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-06 14:49:00',
#   'game_id': 23244926,
#   'game_length': 16,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['Weedcraft'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-06 13:42:00',
#   'game_id': 23244840,
#   'game_length': 9,
#   'game_type': 'Solo',
#   'map': 'Northern Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['feng1987'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-06 13:24:00',
#   'game_id': 23244820,
#   'game_length': 12,
#   'game_type': 'Solo',
#   'map': 'Northern Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['zhongdw'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-06 04:00:00',
#   'game_id': 23244524,
#   'game_length': 16,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['lazy'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-06 03:38:00',
#   'game_id': 23244514,
#   'game_length': 18,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['AnoM'],
#   'team_two': ['helloitsme'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-06 03:17:00',
#   'game_id': 23244499,
#   'game_length': 13,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['AnoM'],
#   'team_two': ['Killaraz'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-06 02:55:00',
#   'game_id': 23244484,
#   'game_length': 19,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['AnoM'],
#   'team_two': ['Cas9'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-06 02:33:00',
#   'game_id': 23244464,
#   'game_length': 13,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['MuscleMike'],
#   'winner': ['MuscleMike']},
#  {'date': '2019-02-06 02:14:00',
#   'game_id': 23244448,
#   'game_length': 18,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['AnoM'],
#   'team_two': ['boo]is[back-123'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-06 01:44:00',
#   'game_id': 23244422,
#   'game_length': 21,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['FierCe[GGL]'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-06 01:17:00',
#   'game_id': 23244397,
#   'game_length': 0,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['Clide'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-06 01:09:00',
#   'game_id': 23244391,
#   'game_length': 13,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['Dr.Ice'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-06 00:54:00',
#   'game_id': 23244380,
#   'game_length': 0,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['AnoM'],
#   'team_two': ['nayonarvaez'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-05 15:03:00',
#   'game_id': 23243513,
#   'game_length': 20,
#   'game_type': 'Solo',
#   'map': 'Concealed Hill',
#   'team_one': ['AnoM'],
#   'team_two': ['Zeke'],
#   'winner': ['Zeke']},
#  {'date': '2019-02-05 14:38:00',
#   'game_id': 23243483,
#   'game_length': 21,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['ArianaGrande'],
#   'winner': ['ArianaGrande']},
#  {'date': '2019-02-05 13:44:00',
#   'game_id': 23243422,
#   'game_length': 36,
#   'game_type': 'Solo',
#   'map': 'Amazonia',
#   'team_one': ['AnoM'],
#   'team_two': ['RAGE.Believe'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-05 01:59:00',
#   'game_id': 23243068,
#   'game_length': 0,
#   'game_type': 'Solo',
#   'map': 'Last Refuge',
#   'team_one': ['AnoM'],
#   'team_two': ['Kntn89'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-05 01:57:00',
#   'game_id': 23243066,
#   'game_length': 0,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['NebtuneR3turns'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-05 01:31:00',
#   'game_id': 23243011,
#   'game_length': 23,
#   'game_type': 'Solo',
#   'map': 'Last Refuge',
#   'team_one': ['AnoM'],
#   'team_two': ['cutegirl90'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-05 00:33:00',
#   'game_id': 23242941,
#   'game_length': 23,
#   'game_type': 'Solo',
#   'map': 'Amazonia',
#   'team_one': ['AnoM'],
#   'team_two': ['Gatzu-'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-05 00:00:00',
#   'game_id': 23242907,
#   'game_length': 10,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['AnoM'],
#   'team_two': ['jams'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-04 23:48:00',
#   'game_id': 23242892,
#   'game_length': 10,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['AnoM'],
#   'team_two': ['GrumpyKoala'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-04 23:35:00',
#   'game_id': 23242875,
#   'game_length': 13,
#   'game_type': 'Solo',
#   'map': 'Last Refuge',
#   'team_one': ['AnoM'],
#   'team_two': ['Mijail.Bulgalov'],
#   'winner': ['Mijail.Bulgalov']},
#  {'date': '2019-02-04 23:20:00',
#   'game_id': 23242857,
#   'game_length': 16,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['AnoM'],
#   'team_two': ['InFs]Psycho'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-04 22:59:00',
#   'game_id': 23242834,
#   'game_length': 28,
#   'game_type': 'Solo',
#   'map': 'Northern Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['FierCe[GGL]'],
#   'winner': ['FierCe[GGL]']},
#  {'date': '2019-02-04 22:29:00',
#   'game_id': 23242785,
#   'game_length': 9,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['ABCD'],
#   'winner': ['ABCD']},
#  {'date': '2019-02-04 22:19:00',
#   'game_id': 23242769,
#   'game_length': 5,
#   'game_type': 'Solo',
#   'map': 'Last Refuge',
#   'team_one': ['AnoM'],
#   'team_two': ['gimmeprimesubs'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-04 21:07:00',
#   'game_id': 23242659,
#   'game_length': 11,
#   'game_type': 'Solo',
#   'map': 'Amazonia',
#   'team_one': ['AnoM'],
#   'team_two': ['REDK.KS'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-04 20:49:00',
#   'game_id': 23242630,
#   'game_length': 19,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['TheRearAdmiral'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-04 18:43:00',
#   'game_id': 23242430,
#   'game_length': 14,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['AnoM'],
#   'team_two': ['dieWende'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-04 18:26:00',
#   'game_id': 23242400,
#   'game_length': 0,
#   'game_type': 'Solo',
#   'map': 'Northern Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['dupe'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-04 18:00:00',
#   'game_id': 23242351,
#   'game_length': 24,
#   'game_type': 'Solo',
#   'map': 'Last Refuge',
#   'team_one': ['AnoM'],
#   'team_two': ['ABCD'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-04 15:20:00',
#   'game_id': 23242086,
#   'game_length': 12,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['MatarreyeS'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-04 02:39:00',
#   'game_id': 23241597,
#   'game_length': 10,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['AnoM'],
#   'team_two': ['InFs]DURIN'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-04 01:48:00',
#   'game_id': 23241555,
#   'game_length': 21,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['AnoM'],
#   'team_two': ['Weedcraft'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-04 01:19:00',
#   'game_id': 23241528,
#   'game_length': 8,
#   'game_type': 'Solo',
#   'map': 'Concealed Hill',
#   'team_one': ['AnoM'],
#   'team_two': ['Gusty'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-04 00:55:00',
#   'game_id': 23241503,
#   'game_length': 17,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['AnoM'],
#   'team_two': ['Runaground'],
#   'winner': ['Runaground']},
#  {'date': '2019-02-04 00:36:00',
#   'game_id': 23241485,
#   'game_length': 9,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['AnoM'],
#   'team_two': ['Susifer'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-04 00:18:00',
#   'game_id': 23241461,
#   'game_length': 17,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['AnoM'],
#   'team_two': ['Bronco'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-03 23:59:00',
#   'game_id': 23241434,
#   'game_length': 4,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['AnoM'],
#   'team_two': ['FierCe[GGL]'],
#   'winner': ['FierCe[GGL]']},
#  {'date': '2019-02-03 23:21:00',
#   'game_id': 23241389,
#   'game_length': 11,
#   'game_type': 'Solo',
#   'map': 'Concealed Hill',
#   'team_one': ['AnoM'],
#   'team_two': ['zhibo'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-03 22:57:00',
#   'game_id': 23241351,
#   'game_length': 14,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['AnoM'],
#   'team_two': ['Hco'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-03 21:39:00',
#   'game_id': 23241233,
#   'game_length': 10,
#   'game_type': 'Solo',
#   'map': 'Northern Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['Bozi'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-03 21:26:00',
#   'game_id': 23241217,
#   'game_length': 0,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['likeKNIVES'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-03 21:16:00',
#   'game_id': 23241203,
#   'game_length': 9,
#   'game_type': 'Solo',
#   'map': 'Amazonia',
#   'team_one': ['AnoM'],
#   'team_two': ['ActionJackson'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-03 20:56:00',
#   'game_id': 23241171,
#   'game_length': 19,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['AnoM'],
#   'team_two': ['FierCe[GGL]'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-03 20:29:00',
#   'game_id': 23241133,
#   'game_length': 10,
#   'game_type': 'Solo',
#   'map': 'Northern Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['killtheoldman'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-03 20:11:00',
#   'game_id': 23241104,
#   'game_length': 17,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['Mijail.Bulgalov'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-03 19:47:00',
#   'game_id': 23241060,
#   'game_length': 12,
#   'game_type': 'Solo',
#   'map': 'Last Refuge',
#   'team_one': ['AnoM'],
#   'team_two': ['Bronco'],
#   'winner': ['Bronco']},
#  {'date': '2019-02-03 19:25:00',
#   'game_id': 23241035,
#   'game_length': 16,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['Catharsis'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-03 19:04:00',
#   'game_id': 23241007,
#   'game_length': 12,
#   'game_type': 'Solo',
#   'map': 'Amazonia',
#   'team_one': ['AnoM'],
#   'team_two': ['RelearningWc3'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-03 18:50:00',
#   'game_id': 23240990,
#   'game_length': 10,
#   'game_type': 'Solo',
#   'map': 'Last Refuge',
#   'team_one': ['AnoM'],
#   'team_two': ['Fithydenk'],
#   'winner': ['Fithydenk']},
#  {'date': '2019-02-03 14:29:00',
#   'game_id': 23240558,
#   'game_length': 9,
#   'game_type': 'Solo',
#   'map': 'Amazonia',
#   'team_one': ['AnoM'],
#   'team_two': ['Pilule23'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-03 14:05:00',
#   'game_id': 23240519,
#   'game_length': 18,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['kyloc'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-03 13:40:00',
#   'game_id': 23240470,
#   'game_length': 11,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['AnoM'],
#   'team_two': ['lawling123'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-03 13:27:00',
#   'game_id': 23240448,
#   'game_length': 4,
#   'game_type': 'Solo',
#   'map': 'Concealed Hill',
#   'team_one': ['AnoM'],
#   'team_two': ['Wolves'],
#   'winner': ['Wolves']},
#  {'date': '2019-02-03 13:11:00',
#   'game_id': 23240425,
#   'game_length': 8,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['AnoM'],
#   'team_two': ['Andreko'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-03 12:14:00',
#   'game_id': 23240351,
#   'game_length': 22,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['AnoM'],
#   'team_two': ['ovelix'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-03 01:40:00',
#   'game_id': 23239937,
#   'game_length': 13,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['AnoM'],
#   'team_two': ['Weedcraft'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-03 01:25:00',
#   'game_id': 23239923,
#   'game_length': 11,
#   'game_type': 'Solo',
#   'map': 'Northern Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['720S'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-02 23:43:00',
#   'game_id': 23239802,
#   'game_length': 10,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['AnoM'],
#   'team_two': ['13atosai'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-02 22:42:00',
#   'game_id': 23239699,
#   'game_length': 10,
#   'game_type': 'Solo',
#   'map': 'Amazonia',
#   'team_one': ['AnoM'],
#   'team_two': ['Noobie'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-02 22:29:00',
#   'game_id': 23239679,
#   'game_length': 10,
#   'game_type': 'Solo',
#   'map': 'Amazonia',
#   'team_one': ['AnoM'],
#   'team_two': ['Andreko'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-02 22:13:00',
#   'game_id': 23239655,
#   'game_length': 14,
#   'game_type': 'Solo',
#   'map': 'Northern Isles',
#   'team_one': ['AnoM'],
#   'team_two': ['htrt'],
#   'winner': ['htrt']},
#  {'date': '2019-02-02 19:47:00',
#   'game_id': 23239422,
#   'game_length': 8,
#   'game_type': 'Solo',
#   'map': 'Last Refuge',
#   'team_one': ['AnoM'],
#   'team_two': ['IhsahN'],
#   'winner': ['AnoM']},
#  {'date': '2019-02-02 19:35:00',
#   'game_id': 23239405,
#   'game_length': 10,
# ...
#   'game_id': 23131794,
#   'game_length': 10,
#   'game_type': 'Arranged 2v2',
#   'map': 'Phantom Grove_ L V',
#   'team_one': ['SeriousPlay', 'Ceron'],
#   'team_two': ['Duffio', ' Gaia[GGL]'],
#   'winner': ['SeriousPlay', 'Ceron']},
#  {'date': '2018-04-17 18:20:00',
#   'game_id': 23129223,
#   'game_length': 11,
#   'game_type': 'Tournament',
#   'map': 'Turtle Rock',
#   'team_one': ['Ceron'],
#   'team_two': ['tuesdayynight'],
#   'winner': ['Ceron']},
#  {'date': '2018-04-17 17:52:00',
#   'game_id': 23129191,
#   'game_length': 11,
#   'game_type': 'Tournament',
#   'map': 'Turtle Rock',
#   'team_one': ['Ceron'],
#   'team_two': ['BluntsGLI'],
#   'winner': ['Ceron']},
#  {'date': '2018-04-17 17:40:00',
#   'game_id': 23129177,
#   'game_length': 0,
#   'game_type': 'Tournament',
#   'map': 'Turtle Rock',
#   'team_one': ['Ceron'],
#   'team_two': ['KoalaMYummy'],
#   'winner': ['Ceron']},
#  {'date': '2018-04-16 19:49:00',
#   'game_id': 23126870,
#   'game_length': 14,
#   'game_type': 'Solo',
#   'map': 'Plunder Isle_ L V',
#   'team_one': ['Ceron'],
#   'team_two': ['FatRedBelly'],
#   'winner': ['Ceron']},
#  {'date': '2018-04-16 18:27:00',
#   'game_id': 23126724,
#   'game_length': 15,
#   'game_type': 'Solo',
#   'map': 'The Two Rivers_ L V',
#   'team_one': ['Ceron'],
#   'team_two': ['iTunes'],
#   'winner': ['Ceron']},
#  {'date': '2018-04-16 17:54:00',
#   'game_id': 23126667,
#   'game_length': 13,
#   'game_type': 'Solo',
#   'map': 'Last Refuge-1',
#   'team_one': ['Ceron'],
#   'team_two': ['workwork'],
#   'winner': ['Ceron']},
#  {'date': '2018-04-16 17:23:00',
#   'game_id': 23126635,
#   'game_length': 17,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['Ceron'],
#   'team_two': ['TrainingNE'],
#   'winner': ['Ceron']},
#  {'date': '2018-04-15 22:30:00',
#   'game_id': 23125685,
#   'game_length': 9,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['Ceron'],
#   'team_two': ['naorchope'],
#   'winner': ['naorchope']},
#  {'date': '2018-04-15 22:05:00',
#   'game_id': 23125645,
#   'game_length': 17,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['Ceron'],
#   'team_two': ["I'mNotSurprised"],
#   'winner': ['Ceron']},
#  {'date': '2018-04-15 21:44:00',
#   'game_id': 23125555,
#   'game_length': 14,
#   'game_type': 'Solo',
#   'map': 'Plunder Isle_ L V',
#   'team_one': ['Ceron'],
#   'team_two': ['TABLERO'],
#   'winner': ['Ceron']},
#  {'date': '2018-04-15 21:26:00',
#   'game_id': 23125535,
#   'game_length': 9,
#   'game_type': 'Solo',
#   'map': 'Twisted Meadows',
#   'team_one': ['Ceron'],
#   'team_two': ['HumanKingTom'],
#   'winner': ['Ceron']},
#  {'date': '2018-04-15 21:10:00',
#   'game_id': 23125508,
#   'game_length': 20,
#   'game_type': 'Solo',
#   'map': 'Flood Plains1v1_ L V',
#   'team_one': ['Ceron'],
#   'team_two': ['StarZ'],
#   'winner': ['Ceron']},
#  {'date': '2018-04-15 20:23:00',
#   'game_id': 23125386,
#   'game_length': 15,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['Ceron'],
#   'team_two': ['lua'],
#   'winner': ['Ceron']},
#  {'date': '2018-04-12 18:50:00',
#   'game_id': 23119503,
#   'game_length': 4,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['Ceron'],
#   'team_two': ['Gitch'],
#   'winner': ['Ceron']},
#  {'date': '2018-04-12 18:44:00',
#   'game_id': 23119498,
#   'game_length': 15,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['Ceron'],
#   'team_two': ['Sully'],
#   'winner': ['Sully']},
#  {'date': '2018-04-12 18:27:00',
#   'game_id': 23119473,
#   'game_length': 12,
#   'game_type': 'Solo',
#   'map': 'Amazonia',
#   'team_one': ['Ceron'],
#   'team_two': ['DRfrightenstein'],
#   'winner': ['Ceron']},
#  {'date': '2018-04-11 23:58:00',
#   'game_id': 23118644,
#   'game_length': 9,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['Ceron'],
#   'team_two': ['POKEMON'],
#   'winner': ['POKEMON']},
#  {'date': '2018-04-11 23:38:00',
#   'game_id': 23118616,
#   'game_length': 9,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['Ceron'],
#   'team_two': ['cutegirl90'],
#   'winner': ['Ceron']},
#  {'date': '2018-04-11 23:16:00',
#   'game_id': 23118574,
#   'game_length': 15,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand_ L V',
#   'team_one': ['Ceron'],
#   'team_two': ['SwordPuppy'],
#   'winner': ['Ceron']},
#  {'date': '2018-04-11 22:52:00',
#   'game_id': 23118491,
#   'game_length': 10,
#   'game_type': 'Solo',
#   'map': 'Last Refuge-1',
#   'team_one': ['Ceron'],
#   'team_two': ['Flame[skynet]'],
#   'winner': ['Ceron']},
#  {'date': '2018-04-11 22:40:00',
#   'game_id': 23118456,
#   'game_length': 13,
#   'game_type': 'Solo',
#   'map': 'Last Refuge-1',
#   'team_one': ['Ceron'],
#   'team_two': ['TheAbuser'],
#   'winner': ['TheAbuser']},
#  {'date': '2018-04-11 16:03:00',
#   'game_id': 23117787,
#   'game_length': 7,
#   'game_type': 'Solo',
#   'map': 'Road To Stratholme_ L V',
#   'team_one': ['Ceron'],
#   'team_two': ['ShivAn-TiMe'],
#   'winner': ['Ceron']},
#  {'date': '2018-04-11 15:50:00',
#   'game_id': 23117771,
#   'game_length': 12,
#   'game_type': 'Solo',
#   'map': 'Amazonia',
#   'team_one': ['Ceron'],
#   'team_two': ['TPowerfOneLugia'],
#   'winner': ['TPowerfOneLugia']},
#  {'date': '2018-04-10 21:55:00',
#   'game_id': 23116755,
#   'game_length': 9,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['Ceron'],
#   'team_two': ['gauddy'],
#   'winner': ['Ceron']},
#  {'date': '2018-04-10 21:38:00',
#   'game_id': 23116723,
#   'game_length': 13,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['Ceron'],
#   'team_two': ['Boo-craft'],
#   'winner': ['Boo-craft']},
#  {'date': '2018-04-10 21:24:00',
#   'game_id': 23116699,
#   'game_length': 13,
#   'game_type': 'Solo',
#   'map': 'The Two Rivers_ L V',
#   'team_one': ['Ceron'],
#   'team_two': ['FatRedBelly'],
#   'winner': ['Ceron']},
#  {'date': '2018-04-10 20:22:00',
#   'game_id': 23116570,
#   'game_length': 9,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['Ceron'],
#   'team_two': ['MelancholyMood'],
#   'winner': ['MelancholyMood']},
#  {'date': '2018-04-10 20:11:00',
#   'game_id': 23116553,
#   'game_length': 18,
#   'game_type': 'Solo',
#   'map': 'Plunder Isle_ L V',
#   'team_one': ['Ceron'],
#   'team_two': ['PSILoveYou'],
#   'winner': ['Ceron']},
#  {'date': '2018-03-20 18:25:00',
#   'game_id': 23076237,
#   'game_length': 5,
#   'game_type': 'Tournament',
#   'map': 'Turtle Rock',
#   'team_one': ['Ceron'],
#   'team_two': ['mongshell_tong'],
#   'winner': ['Ceron']},
#  {'date': '2018-03-20 18:17:00',
#   'game_id': 23076235,
#   'game_length': 18,
#   'game_type': 'Tournament',
#   'map': 'Echo Isles',
#   'team_one': ['Ceron'],
#   'team_two': ['Michae1'],
#   'winner': ['Ceron']},
#  {'date': '2018-03-20 15:54:00',
#   'game_id': 23075233,
#   'game_length': 13,
#   'game_type': 'Solo',
#   'map': 'Melting Valley',
#   'team_one': ['Ceron'],
#   'team_two': ['DeLi'],
#   'winner': ['Ceron']},
#  {'date': '2018-03-17 12:55:00',
#   'game_id': 23069482,
#   'game_length': 8,
#   'game_type': 'Solo',
#   'map': 'Twisted Meadows',
#   'team_one': ['Ceron'],
#   'team_two': ['NATTYLIGHT'],
#   'winner': ['Ceron']},
#  {'date': '2018-03-13 17:55:00',
#   'game_id': 23064025,
#   'game_length': 12,
#   'game_type': 'Tournament',
#   'map': 'Gnoll Wood',
#   'team_one': ['sayso.', 'Ceron'],
#   'team_two': ['DitEjM', ' iNt]aux_X'],
#   'winner': ['sayso.', 'Ceron']},
#  {'date': '2018-03-13 17:40:00',
#   'game_id': 23063268,
#   'game_length': 14,
#   'game_type': 'Solo',
#   'map': 'Melting Valley',
#   'team_one': ['Ceron'],
#   'team_two': ['SLiNK'],
#   'winner': ['Ceron']},
#  {'date': '2018-03-13 17:24:00',
#   'game_id': 23063251,
#   'game_length': 7,
#   'game_type': 'Solo',
#   'map': 'Echo Isles',
#   'team_one': ['Ceron'],
#   'team_two': ['ENTOURAGE'],
#   'winner': ['Ceron']},
#  {'date': '2018-03-11 20:17:00',
#   'game_id': 23060317,
#   'game_length': 22,
#   'game_type': 'Tournament',
#   'map': 'Twisted Meadows',
#   'team_one': ['Ceron'],
#   'team_two': ['waguci'],
#   'winner': ['Ceron']},
#  {'date': '2018-03-11 19:36:00',
#   'game_id': 23060315,
#   'game_length': 15,
#   'game_type': 'Tournament',
#   'map': 'Lost Temple',
#   'team_one': ['Ceron'],
#   'team_two': ['sayso.'],
#   'winner': ['Ceron']},
#  {'date': '2018-03-11 18:51:00',
#   'game_id': 23060312,
#   'game_length': 6,
#   'game_type': 'Tournament',
#   'map': 'Turtle Rock',
#   'team_one': ['Ceron'],
#   'team_two': ['MaGazEk'],
#   'winner': ['Ceron']},
#  {'date': '2018-03-11 16:06:00',
#   'game_id': 23060288,
#   'game_length': 27,
#   'game_type': 'Tournament',
#   'map': 'Twisted Meadows',
#   'team_one': ['Ceron'],
#   'team_two': ['TrainingNE'],
#   'winner': ['Ceron']},
#  {'date': '2018-03-11 15:29:00',
#   'game_id': 23060244,
#   'game_length': 11,
#   'game_type': 'Tournament',
#   'map': 'Lost Temple',
#   'team_one': ['Ceron'],
#   'team_two': ['SilentSniper'],
#   'winner': ['Ceron']},
#  {'date': '2018-03-11 15:16:00',
#   'game_id': 23060222,
#   'game_length': 12,
#   'game_type': 'Tournament',
#   'map': 'Turtle Rock',
#   'team_one': ['Ceron'],
#   'team_two': ['deepcobra'],
#   'winner': ['Ceron']},
#  {'date': '2018-03-11 14:38:00',
#   'game_id': 23059279,
#   'game_length': 18,
#   'game_type': 'Solo',
#   'map': 'Gnoll Wood',
#   'team_one': ['Ceron'],
#   'team_two': ['ADDTOKODOFOLDER'],
#   'winner': ['ADDTOKODOFOLDER']},
#  {'date': '2018-03-11 14:17:00',
#   'game_id': 23059249,
#   'game_length': 9,
#   'game_type': 'Solo',
#   'map': 'Turtle Rock',
#   'team_one': ['Ceron'],
#   'team_two': ['bored.'],
#   'winner': ['Ceron']},
#  {'date': '2018-03-11 13:59:00',
#   'game_id': 23059207,
#   'game_length': 10,
#   'game_type': 'Solo',
#   'map': 'Secret Valley',
#   'team_one': ['Ceron'],
#   'team_two': ['Dainbramage'],
#   'winner': ['Ceron']},
#  {'date': '2018-03-10 18:27:00',
#   'game_id': 23057813,
#   'game_length': 22,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand',
#   'team_one': ['Ceron'],
#   'team_two': ['RenditionRG_FF'],
#   'winner': ['RenditionRG_FF']},
#  {'date': '2018-03-08 20:22:00',
#   'game_id': 23054888,
#   'game_length': 15,
#   'game_type': 'Tournament',
#   'map': 'Terenas Stand',
#   'team_one': ['Ceron'],
#   'team_two': ['Bughuul'],
#   'winner': ['Ceron']},
#  {'date': '2018-03-08 19:45:00',
#   'game_id': 23054862,
#   'game_length': 6,
#   'game_type': 'Tournament',
#   'map': 'Terenas Stand',
#   'team_one': ['Ceron'],
#   'team_two': ['Azor-Ahai'],
#   'winner': ['Ceron']},
#  {'date': '2018-03-08 19:35:00',
#   'game_id': 23054849,
#   'game_length': 6,
#   'game_type': 'Tournament',
#   'map': 'Terenas Stand',
#   'team_one': ['Ceron'],
#   'team_two': ['bigcisback'],
#   'winner': ['Ceron']},
#  {'date': '2018-03-08 19:13:00',
#   'game_id': 23054824,
#   'game_length': 4,
#   'game_type': 'Tournament',
#   'map': 'Terenas Stand',
#   'team_one': ['Ceron'],
#   'team_two': ['sayso.'],
#   'winner': ['sayso.']},
#  {'date': '2018-03-03 19:09:00',
#   'game_id': 23045626,
#   'game_length': 10,
#   'game_type': 'Solo',
#   'map': 'Twisted Meadows',
#   'team_one': ['Ceron'],
#   'team_two': ['FatRedBelly'],
#   'winner': ['FatRedBelly']},
#  {'date': '2018-03-03 18:56:00',
#   'game_id': 23045511,
#   'game_length': 15,
#   'game_type': 'Arranged 2v2',
#   'map': 'Centaur Grove',
#   'team_one': ['say[so', 'Ceron'],
#   'team_two': ['KingKumar', ' RecklessOne'],
#   'winner': ['say[so', 'Ceron']},
#  {'date': '2018-03-03 17:54:00',
#   'game_id': 23045448,
#   'game_length': 18,
#   'game_type': 'Solo',
#   'map': 'Terenas Stand',
#   'team_one': ['Ceron'],
#   'team_two': ['Gitch'],
#   'winner': ['Ceron']},
#  {'date': '2017-12-12 18:09:00',
#   'game_id': 22919166,
#   'game_length': 11,
#   'game_type': 'Tournament',
#   'map': 'Turtle Rock',
#   'team_one': ['Ceron'],
#   'team_two': ['mongshell_tong'],
#   'winner': ['Ceron']},
#  {'date': '2017-12-12 17:54:00',
#   'game_id': 22919151,
#   'game_length': 14,
#   'game_type': 'Tournament',
#   'map': 'Turtle Rock',
#   'team_one': ['Ceron'],
#   'team_two': ['Mantalo'],
#   'winner': ['Ceron']},
#  {'date': '2017-09-26 17:30:00',
#   'game_id': 22806738,
#   'game_length': 27,
#   'game_type': 'Solo',
#   'map': 'Secret Valley',
#   'team_one': ['Ceron'],
#   'team_two': ['metal515'],
#   'winner': ['metal515']},
#  {'date': '2017-09-25 23:02:00',
#   'game_id': 22805780,
#   'game_length': 12,
#   'game_type': 'Solo',
#   'map': 'Secret Valley',
#   'team_one': ['Ceron'],
#   'team_two': ['SheWasA.DDRdiva'],
#   'winner': ['Ceron']},
#  {'date': '2017-09-21 23:33:00',
#   'game_id': 22799480,
#   'game_length': 12,
#   'game_type': 'Tournament',
#   'map': 'Terenas Stand',
#   'team_one': ['Ceron'],
#   'team_two': ['the_tree_shells'],
#   'winner': ['the_tree_shells']},
#  {'date': '2017-09-21 23:13:00',
#   'game_id': 22799104,
#   'game_length': 12,
#   'game_type': 'Solo',
#   'map': 'Twisted Meadows',
#   'team_one': ['Ceron'],
#   'team_two': ['serrymy'],
#   'winner': ['serrymy']},
#  {'date': '2017-09-21 22:16:00',
#   'game_id': 22799475,
#   'game_length': 6,
#   'game_type': 'Tournament',
#   'map': 'Terenas Stand',
#   'team_one': ['Ceron'],
#   'team_two': ['GGnoRE'],
#   'winner': ['Ceron']},
#  {'date': '2017-09-21 21:20:00',
#   'game_id': 22799471,
#   'game_length': 27,
#   'game_type': 'Tournament',
#   'map': 'Terenas Stand',
#   'team_one': ['Ceron'],
#   'team_two': ['the_tree_shells'],
#   'winner': ['Ceron']},
#  {'date': '2017-09-21 20:52:00',
#   'game_id': 22799459,
#   'game_length': 14,
#   'game_type': 'Tournament',
#   'map': 'Terenas Stand',
#   'team_one': ['Ceron'],
#   'team_two': ['Jiggly_Puff'],
#   'winner': ['Ceron']},
#  {'date': '2017-09-21 20:12:00',
#   'game_id': 22799429,
#   'game_length': 18,
#   'game_type': 'Tournament',
#   'map': 'Terenas Stand',
#   'team_one': ['Ceron'],
#   'team_two': ['JustGotWc3'],
#   'winner': ['Ceron']},
#  {'date': '2017-09-21 19:47:00',
#   'game_id': 22799381,
#   'game_length': 5,
#   'game_type': 'Tournament',
#   'map': 'Terenas Stand',
#   'team_one': ['Ceron'],
#   'team_two': ['mojoidk'],
#   'winner': ['Ceron']},
#  {'date': '2017-09-21 19:41:00',
#   'game_id': 22799365,
#   'game_length': 13,
#   'game_type': 'Tournament',
#   'map': 'Terenas Stand',
#   'team_one': ['Ceron'],
#   'team_two': ['og.pitcoe'],
#   'winner': ['Ceron']},
#  {'date': '2017-09-21 19:26:00',
#   'game_id': 22799333,
#   'game_length': 14,
#   'game_type': 'Tournament',
#   'map': 'Terenas Stand',
#   'team_one': ['Ceron'],
#   'team_two': ['Maniac-'],
#   'winner': ['Maniac-']},
#  {'date': '2017-09-19 20:02:00',
#   'game_id': 22795976,
#   'game_length': 0,
#   'game_type': 'Random 4v4',
#   'map': 'Deadlands',
#   'team_one': ['cumslinger', ' blehhh', ' Subverito', 'Ceron'],
#   'team_two': ['otsegolectric', ' L1ghtweight', ' Bughuul', ' Bobettes_Sales'],
#   'winner': ['cumslinger', ' blehhh', ' Subverito', 'Ceron']},
#  {'date': '2017-09-11 19:39:00',
#   'game_id': 22783279,
#   'game_length': 8,
#   'game_type': 'Arranged 2v2',
#   'map': 'Wetlands',
#   'team_one': ['say[so', 'Ceron'],
#   'team_two': ['choboed', ' TucKnY'],
#   'winner': ['say[so', 'Ceron']},
#  {'date': '2017-09-10 22:10:00',
#   'game_id': 22782132,
#   'game_length': 10,
#   'game_type': 'Arranged 2v2',
#   'map': 'Phantom Grove',
#   'team_one': ['say[so', 'Ceron'],
#   'team_two': ['jeremy', ' Tessor'],
#   'winner': ['say[so', 'Ceron']},
#  {'date': '2017-09-10 21:50:00',
#   'game_id': 22782043,
#   'game_length': 8,
#   'game_type': 'Arranged 2v2',
#   'map': 'Tidewater Glades',
#   'team_one': ['say[so', 'Ceron'],
#   'team_two': ['Dcaro', ' Lartas'],
#   'winner': ['say[so', 'Ceron']},
#  {'date': '2017-09-10 21:41:00',
#   'game_id': 22782042,
#   'game_length': 7,
#   'game_type': 'Arranged 2v2',
#   'map': 'Lost Temple',
#   'team_one': ['say[so', 'Ceron'],
#   'team_two': ['Orcasim', ' sdthh'],
#   'winner': ['say[so', 'Ceron']},
#  {'date': '2017-09-01 17:38:00',
#   'game_id': 22767052,
#   'game_length': 27,
#   'game_type': 'Solo',
#   'map': 'Secret Valley',
#   'team_one': ['Ceron'],
#   'team_two': ['_______________'],
#   'winner': ['Ceron']},
#  {'date': '2017-08-29 15:59:00',
#   'game_id': 22763026,
#   'game_length': 17,
#   'game_type': 'Random 4v4',
#   'map': 'Battleground',
#   'team_one': ['KBilly', ' Stonewall', ' DonkeyBrains', 'Ceron'],
#   'team_two': ['Riceer', ' Mr.Spitz', ' katara07', ' ThugMaSteR'],
#   'winner': ['KBilly', ' Stonewall', ' DonkeyBrains', 'Ceron']},
#  {'date': '2017-08-28 21:26:00',
#   'game_id': 22762241,
#   'game_length': 22,
#   'game_type': 'Random 4v4',
#   'map': 'Deadlock',
#   'team_one': ['TucKnY', ' Samuelljackson-', ' MrMacaroni', 'Ceron'],
#   'team_two': ['Protogod', ' blehhh', ' DeathByStealth', ' MajorNewbs'],
#   'winner': ['TucKnY', ' Samuelljackson-', ' MrMacaroni', 'Ceron']},
#  ...]

# %%
'./data_backfill/{}.json'.format(server)
# Out:
# './data_backfill/azeroth.json'

# %%
(
# Out:
#   File "<ipython-input-19-abd48b2e7f8c>", line 1
#     (
#      ^
# SyntaxError: unexpected EOF while parsing
